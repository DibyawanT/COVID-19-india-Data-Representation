# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('covid_19_india.csv')
data2=pd.read_csv('AgeGroupDetails.csv')
data3=pd.read_csv('HospitalBedsIndia.csv')

# %%
data
# Out:
#        Sno      Date     Time       State/UT ConfirmedIndianNational  \
# 0        1  30/01/20  6:00 PM         Kerala                       1
# 1        2  31/01/20  6:00 PM         Kerala                       1
# 2        3  1/2/2020  6:00 PM         Kerala                       2
# 3        4  2/2/2020  6:00 PM         Kerala                       3
# 4        5  3/2/2020  6:00 PM         Kerala                       3
# ...    ...       ...      ...            ...                     ...
# 1765  1766  9/5/2020  8:00 AM      Telengana                       -
# 1766  1767  9/5/2020  8:00 AM        Tripura                       -
# 1767  1768  9/5/2020  8:00 AM    Uttarakhand                       -
# 1768  1769  9/5/2020  8:00 AM  Uttar Pradesh                       -
# 1769  1770  9/5/2020  8:00 AM    West Bengal                       -
#
#      ConfirmedForeignNational  Cured  Deaths  Confirmed
# 0                           0      0       0          1
# ...

# %%
first=data.head(30)
first
# Out:
#     Sno       Date     Time State/UT ConfirmedIndianNational  \
# 0     1   30/01/20  6:00 PM   Kerala                       1
# 1     2   31/01/20  6:00 PM   Kerala                       1
# 2     3   1/2/2020  6:00 PM   Kerala                       2
# 3     4   2/2/2020  6:00 PM   Kerala                       3
# 4     5   3/2/2020  6:00 PM   Kerala                       3
# 5     6   4/2/2020  6:00 PM   Kerala                       3
# 6     7   5/2/2020  6:00 PM   Kerala                       3
# 7     8   6/2/2020  6:00 PM   Kerala                       3
# 8     9   7/2/2020  6:00 PM   Kerala                       3
# 9    10   8/2/2020  6:00 PM   Kerala                       3
# 10   11   9/2/2020  6:00 PM   Kerala                       3
# 11   12  10/2/2020  6:00 PM   Kerala                       3
# 12   13  11/2/2020  6:00 PM   Kerala                       3
# 13   14  12/2/2020  6:00 PM   Kerala                       3
# ...

# %%
last=data.tail(30)
last
# Out:
#        Sno      Date     Time            State/UT ConfirmedIndianNational  \
# 1740  1741  9/5/2020  8:00 AM               Assam                       -
# 1741  1742  9/5/2020  8:00 AM               Bihar                       -
# 1742  1743  9/5/2020  8:00 AM          Chandigarh                       -
# 1743  1744  9/5/2020  8:00 AM        Chhattisgarh                       -
# 1744  1745  9/5/2020  8:00 AM  Dadar Nagar Haveli                       -
# 1745  1746  9/5/2020  8:00 AM               Delhi                       -
# 1746  1747  9/5/2020  8:00 AM                 Goa                       -
# 1747  1748  9/5/2020  8:00 AM             Gujarat                       -
# 1748  1749  9/5/2020  8:00 AM             Haryana                       -
# 1749  1750  9/5/2020  8:00 AM    Himachal Pradesh                       -
# 1750  1751  9/5/2020  8:00 AM   Jammu and Kashmir                       -
# 1751  1752  9/5/2020  8:00 AM           Jharkhand                       -
# ...

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UT', 'ConfirmedIndianNational',
#        'ConfirmedForeignNational', 'Cured', 'Deaths', 'Confirmed'],
#       dtype='object')

# %%
df=data.groupby('State/UT').sum()
df=df.sort_values('Deaths',axis=0,ascending=False)
df=df.head()

# %% [markdown]
# # Relation of Time With Spread of Virus.

# %%
sns.relplot(x='Confirmed',y='Cured',hue='Deaths',data=data)

# %% [markdown]
# # First Month of Spread

# %%
sns.relplot(x='Confirmed',y='Cured',hue='Deaths',data=first)

# %% [markdown]
# # *Spread in the last month*

# %%
sns.relplot(x='Confirmed',y='Cured',hue='Deaths',data=last)

# %% [markdown]
# # Most Affected States

# %%
df
# Out:
#                   Sno  Cured  Deaths  Confirmed
# State/UT
# Maharashtra     50659  36993   10692     239920
# Gujarat         48638  14715    4810      93703
# Madhya Pradesh  48785  11439    3159      59450
# Delhi           50432  22401    1496      90929
# West Bengal     50146   3756    1166      19721

# %%
g=sns.catplot(x='Confirmed', y="Cured", hue="Deaths", data=df,
                height=6, kind="bar")

# %% [markdown]
# # Relation between Age and Total Cases.

# %%
data2
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%
# 5    6    50-59          77     11.13%
# 6    7    60-69          89     12.86%
# 7    8    70-79          28      4.05%
# 8    9     >=80          10      1.45%
# 9   10  Missing           9      1.30%

# %%
sns.catplot(x='AgeGroup',y='TotalCases',data=data2,
           height=6,kind='bar')

# %%
df=data.groupby('State/UT').sum()
c=df['Confirmed']
c
# Out:
# State/UT
# Andaman and Nicobar Islands       818
# Andhra Pradesh                  33380
# Arunachal Pradesh                  37
# Assam                            1316
# Bihar                            8234
# Chandigarh                       1764
# Chhattisgarh                     1301
# Dadar Nagar Haveli                  4
# Delhi                           90929
# Goa                               292
# Gujarat                         93703
# Haryana                         10682
# Himachal Pradesh                 1269
# Jammu and Kashmir               15371
# Jharkhand                        2074
# Jharkhand#                         45
# Karnataka                       15923
# Kerala                          17779
# Ladakh                           1036
# Madhya Pradesh                  59450
# Maharashtra                    239920
# Manipur                            84
# Meghalaya                         284
# Mizoram                            46
# ...

# %%
data4=pd.merge(data3,c,how='inner',on='State/UT')
data4
# Out:
#     Sno           State/UT NumPrimaryHealthCenters_HMIS  \
# 0     2     Andhra Pradesh                         1417
# 1     3  Arunachal Pradesh                          122
# 2     4              Assam                         1007
# 3     5              Bihar                         2007
# 4     6         Chandigarh                           40
# 5     7       Chhattisgarh                          813
# 6    10              Delhi                          534
# 7    11                Goa                           31
# 8    12            Gujarat                         1770
# 9    13            Haryana                          500
# 10   14   Himachal Pradesh                          516
# 11   16          Jharkhand                          343
# 12   17          Karnataka                         2547
# 13   18             Kerala                          933
# 14   20     Madhya Pradesh                         1420
# 15   21        Maharashtra                         2638
# ...

# %%
sns.catplot(x='State/UT',y='NumUrbanBeds_NHP18',hue='Confirmed',data=data4,
           height=26,kind='bar')
#DOUBLE CLICK TO ZOOM
